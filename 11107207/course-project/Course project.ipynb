# %% [markdown]
# Name - Johnzac Ababio
# ---
# Index - 11107207
# ---
# Class - AREN
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('red_wine.csv')

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
dataset.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
dataset.info
# Out:
# <bound method DataFrame.info of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.describe
# Out:
# <bound method NDFrame.describe of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.shape
# Out:
# (1599, 12)

# %%
type(dataset.shape)
# Out:
# tuple

# %%
dataset.size
# Out:
# 19188

# %%
type(dataset.size)
# Out:
# int

# %%
plt.plot(dataset)

# %%
plt.hist(dataset['fixed acidity'])
plt.xlabel('fixed acidity')
plt.ylabel('Frequency')
plt.title('Distribution of fixed acidity')
plt.show()

# %%
plt.scatter(dataset['pH'],dataset['fixed acidity'])
plt.xlabel('pH')
plt.ylabel('fixed acidity')
plt.title('Relationship between pH and fixed acidity')
plt.show()

# %%
x=(dataset['quality'])
y=(dataset['volatile acidity'])
plt.bar(x,y)
plt.xlabel('quality')
plt.ylabel('volatile acidity')
plt.title('Relationship between quality and volatile acidity')
plt.show()

# %% [markdown]
# ---
# # Histogram Distribution of Fixed Acidity
# ---
#
# ## Introduction
#
# This report presents the distribution of fixed acidity in a given dataset, represented through a bar graph. Fixed acidity is measured on the x-axis, ranging from 0 to 16 with intervals of 2, while the frequency is depicted on the y-axis, ranging from 0 to 500 with intervof 100.
#
# ## Body
# The histogram illustrates therelationship between fixed acidity and frequency. Notably, the maximum frequency is observed in the range of fixed acidity 7-8. As fixed acidity increases beyond this range, the frequency gradually reduces, forming a descending pattern. This suggests that the dataset has a peak concentration of observations around fixed acidity 7-8, with fewer instances at higher and lower acidity levels
#
# ## Conclusion
# In summary, the histogram effectively visualizes the distribution of fixed acidity in the dataset. The concentration of observations is highest between fixed acidity 7-8, providing valuable insights into the predominant acidity levels present t in the data.

# %% [markdown]
# ---
# # Scatter Diagram: Relationship between pH and Fixed Acidity
# ---
#
# ## Introduction
#
# This report explores the relationship between pH and fixed acidity in a given dataset, visualized through a scatter diagram. The y-axis represents fixed acidity, ranging from 0 to 16 with intervals of 2, while the x-axis represents pH, ranging from 2.8 to 4.0 with intervals of
#
# ## Body
# The scatter diagram reveals a distinctive pattern in the relationship between pH and fixed acidity. Notably, a significant concentration of observations is observed between pH 3.1 and 3.6, along with fixed acidity levels ranging from 6 to 10 on the y-axis. This concentration suggests a notable correlation between pH values in the specified range and higher fixed acidity.acidity.
#
# ## Conclusion
#
# In summary, the scatter diagram effectively illustrates the relationship between pH and fixed acidity in the dataset. The dense cluster of points between pH 3.1-3.6 and fixed acidity 6-10 indicates a potential correlation or specific behavior within this range. Further analysis may be warranted to explore the underlying factors contributing to this concentrated relationship between pH and fixed acidity.

# %% [markdown]
# ---
# # Bar Graph: Relationship between Quality and Volatile Acidity
# ---
#
# ## Introduction
#
# This report examines the relationship between quality and volatile acidity in a given dataset, portrayed through a bar graph. The y-axis represents volatile acidity, ranging from 0.0 to 1.6 with intervals of 0.2, while the x-axis represents quality, ranging from 3 to 8 with inter of 1.
#
# ## Body
# The bar graph illustrates a distinct relationship between quality and volatile acidity. Starting at quality level 3 on the x-axis, the bar reaches its highest point at 1.6 volatile acidity. As quality progresses to 4, the bar drops to 1.1, indicating a decrease in volatile acidity. Interestingly, at quality level 5, the bar rises slightly to 1.3, suggesting a distinct relationship. However, as quality continues to increase towards level 8, volatile acidity gradually reduces.
#
# ## Conclusion
# In summary, the bar graph effectively portrays the relationship between quality and volatile acidity. Quality level 3 exhibits the highest volatile acidity, which then decreases at quality level 4, rises slightly at quality level 5, and gradually reduces as quality progresses towards level 8. Further analysis may be necessary to understand the underlying factors contributing to these variations in volatile acidity across different quality levels.
# ity levels.
